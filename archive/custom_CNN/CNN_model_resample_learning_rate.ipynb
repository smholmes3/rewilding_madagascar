# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from opensoundscape import BoxedAnnotations, CNN

# %%
import opensoundscape

# %%
train_labels = pd.read_csv('data/train_labels.csv',index_col=['file', 'start_time', 'end_time'])
val_labels = pd.read_csv('data/val_labels.csv',index_col=['file', 'start_time', 'end_time'])
test_labels = pd.read_csv('data/test_labels.csv',index_col=['file', 'start_time', 'end_time'])
train_labels.head()
# Out:
#                                                                         Hypsipetes_madagascariensis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                             False
#                                                    2.0        4.0                             False
#                                                    4.0        6.0                             False
#                                                    6.0        8.0                             False
#                                                    8.0        10.0                            False
#
#                                                                         Copsychus_albospecularis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                          False
#                                                    2.0        4.0                          False
#                                                    4.0        6.0                          False
#                                                    6.0        8.0                          False
#                                                    8.0        10.0                         False
#
#                                                                         Coracopsis_nigra  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                  False
#                                                    2.0        4.0                  False
#                                                    4.0        6.0                  False
#                                                    6.0        8.0                  False
#                                                    8.0        10.0                 False
#
#                                                                         Dicrurus_forficatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Coua_caerulea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0               False
#                                                    2.0        4.0               False
#                                                    4.0        6.0               False
#                                                    6.0        8.0               False
#                                                    8.0        10.0              False
#
#                                                                         Zosterops_maderaspatanus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                          False
#                                                    2.0        4.0                          False
#                                                    4.0        6.0                          False
#                                                    6.0        8.0                          False
#                                                    8.0        10.0                         False
#
#                                                                         Eurystomus_glaucurus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                      False
#                                                    2.0        4.0                      False
#                                                    4.0        6.0                      False
#                                                    6.0        8.0                      False
#                                                    8.0        10.0                     False
#
#                                                                         Agapornis_canus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 False
#                                                    2.0        4.0                 False
#                                                    4.0        6.0                 False
#                                                    6.0        8.0                 False
#                                                    8.0        10.0                False
#
#                                                                         Saxicola_torquatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                    False
#                                                    2.0        4.0                    False
#                                                    4.0        6.0                    False
#                                                    6.0        8.0                    False
#                                                    8.0        10.0                   False
#
#                                                                         Cyanolanius_madagascarinus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                            False
#                                                    2.0        4.0                            False
#                                                    4.0        6.0                            False
#                                                    6.0        8.0                            False
#                                                    8.0        10.0                           False
#
#                                                                         Leptopterus_chabert  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Nesoenas_picturatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Coua_reynaudii  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                False
#                                                    2.0        4.0                False
#                                                    4.0        6.0                False
#                                                    6.0        8.0                False
#                                                    8.0        10.0               False
#
#                                                                         Ceblepyris_cinereus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Neodrepanis_coruscans  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                       False
#                                                    2.0        4.0                       False
#                                                    4.0        6.0                       False
#                                                    6.0        8.0                       False
#                                                    8.0        10.0                      False
#
#                                                                         Philepitta_castanea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Eulemur_sp  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0            False
#                                                    2.0        4.0            False
#                                                    4.0        6.0            False
#                                                    6.0        8.0            False
#                                                    8.0        10.0           False
#
#                                                                         Coua_cristata  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0               False
#                                                    2.0        4.0               False
#                                                    4.0        6.0               False
#                                                    6.0        8.0               False
#                                                    8.0        10.0              False
#
#                                                                         Treron_australis
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                  False
#                                                    2.0        4.0                  False
#                                                    4.0        6.0                  False
#                                                    6.0        8.0                  False
#                                                    8.0        10.0                 False

# %%
# pick classes to train the model on. These should occur in the annotated data
class_list = ['Hypsipetes_madagascariensis','Copsychus_albospecularis','Coracopsis_nigra','Dicrurus_forficatus','Coua_caerulea','Zosterops_maderaspatanus','Eurystomus_glaucurus','Agapornis_canus','Saxicola_torquatus','Cyanolanius_madagascarinus','Leptopterus_chabert','Nesoenas_picturatus','Coua_reynaudii','Ceblepyris_cinereus','Neodrepanis_coruscans','Philepitta_castanea','Eulemur_sp','Coua_cristata','Treron_australis']

class_list==train_labels.columns.values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
train_labels_resampled = opensoundscape.data_selection.resample(train_labels,n_samples_per_class = 5221, downsample = False,upsample = True)

# %%
import wandb
'''wandb.login()'''#when logging in on a new machine
wandb_session = wandb.init(
    project='Rewilding_Madagascar',
)

# %%
#create new model and change parameters then visualize
# create a CNN and train on the labeled data
model = CNN(architecture='resnet18', sample_duration=2, classes=class_list)

# %%
#changes learning rate over time
#default is wait a certain number of epochs and then multiply by x (step learning)
model.lr_scheduler_params['kwargs']['step_size'] = 10
model.lr_scheduler_params['kwargs']['gamma'] = 0.5

# %%
model.preprocessor.pipeline.bandpass.set(min_f=0,max_f=9000)
model.preprocessor.pipeline.to_spec.params.window_samples = 2048
model.train(train_labels_resampled, val_labels, epochs=20, log_interval=20, num_workers=8, batch_size=256, wandb_session = wandb_session, save_path= '/mnt/class_data/group1_bioacoustics/sheila/model_checkpoints/model_6_resample_learningrate')
wandb_session.finish()
# Out:
# Training Epoch 0
#   0%|          | 0/388 [00:00<?, ?it/s]
# Epoch: 0 [batch 0/388, 0.00%]
# 	Epoch Running Average Loss: 0.840
# 	Most Recent Batch Loss: 0.840
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[30], line 4
#
#       2 model.preprocessor.pipeline.to_spec.params.window_samples = 2048
#
#       3 wandb_session = None
#
# ----> 4 model.train(train_labels_resampled, val_labels, epochs=1, log_interval=200, num_workers=8, batch_size=256, wandb_session = wandb_session, save_path= '/mnt/class_data/group1_bioacoustics/sheila/model_checkpoints/model_2_window_band')
#
#       5 #wandb_session.finish()
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/opensoundscape/ml/cnn.py:1622, in SpectrogramClassifier.train(self, train_df, validation_df, epochs, batch_size, num_workers, save_path, save_interval, log_interval, validation_interval, reset_optimizer, restart_scheduler, invalid_samples_log, raise_errors, wandb_session, progress_bar)
#
#    1615 for epoch in range(epochs):
#
#    1616     # 1 epoch = 1 view of each training sample
#
#    1617     # loss fn, backpropogation, and optimizer step generally occur after each batch
#
#    1618     # validation generally occurs after validation_interval epochs
#
#    1619
#
#    1620     ### Training ###
#
#    1621     self._log(f"\nTraining Epoch {self.current_epoch}")
#
# -> 1622     train_metrics = self._train_epoch(
#
#    1623         train_loader, wandb_session, progress_bar=progress_bar
#
#    1624     )
#
#    1626     #### Validation ###
#
#    1627     if epoch % validation_interval == 0:
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/opensoundscape/ml/cnn.py:1350, in SpectrogramClassifier._train_epoch(self, train_loader, wandb_session, progress_bar)
#
#    1344 batch_loss = []
#
#    1346 for batch_idx, (batch_tensors, batch_labels) in enumerate(
#
#    1347     tqdm(train_loader, disable=not progress_bar)
#
#    1348 ):
#
#    1349     # save loss for each batch; later take average for epoch
#
# -> 1350     loss = self.training_step((batch_tensors, batch_labels), batch_idx)
#
#    1351     batch_loss.append(loss.detach().cpu().numpy())
#
#    1352     ###########
#
#    1353     # Logging #
#
#    1354     ###########
#
#    1355     # log basic train info (used to print every batch)
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/opensoundscape/ml/cnn.py:274, in BaseModule.training_step(self, samples, batch_idx)
#
#     272 y = batch_labels.argmax(dim=1) if self.single_target else batch_labels
#
#     273 # TODO: does not allow soft labels, but some torchmetrics expect long type?
#
# --> 274 batch_metrics = {
#
#     275     f"train_{name}": metric.to(self.device)(
#
#     276         output.detach(), y.detach().long()
#
#     277     ).cpu()
#
#     278     for name, metric in self.torch_metrics.items()
#
#     279 }
#
#     281 if self.lightning_mode:
#
#     282     self.log(
#
#     283         f"train_loss",
#
#     284         loss,
#
#    (...)
#
#     287         batch_size=len(batch_tensors),
#
#     288     )
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/opensoundscape/ml/cnn.py:275, in <dictcomp>(.0)
#
#     272 y = batch_labels.argmax(dim=1) if self.single_target else batch_labels
#
#     273 # TODO: does not allow soft labels, but some torchmetrics expect long type?
#
#     274 batch_metrics = {
#
# --> 275     f"train_{name}": metric.to(self.device)(
#
#     276         output.detach(), y.detach().long()
#
#     277     ).cpu()
#
#     278     for name, metric in self.torch_metrics.items()
#
#     279 }
#
#     281 if self.lightning_mode:
#
#     282     self.log(
#
#     283         f"train_loss",
#
#     284         loss,
#
#    (...)
#
#     287         batch_size=len(batch_tensors),
#
#     288     )
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1735 else:
#
# -> 1736     return self._call_impl(*args, **kwargs)
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1743 # this function, and just call forward.
#
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1747     return forward_call(*args, **kwargs)
#
#    1749 result = None
#
#    1750 called_always_called_hooks = set()
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torchmetrics/metric.py:316, in Metric.forward(self, *args, **kwargs)
#
#     314     self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#
#     315 else:
#
# --> 316     self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#
#     318 return self._forward_cache
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torchmetrics/metric.py:385, in Metric._forward_reduce_state_update(self, *args, **kwargs)
#
#     382 self._enable_grad = True  # allow grads for batch computation
#
#     384 # calculate batch state and compute batch value
#
# --> 385 self.update(*args, **kwargs)
#
#     386 batch_val = self.compute()
#
#     388 # reduce batch and global state
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torchmetrics/metric.py:550, in Metric._wrap_update.<locals>.wrapped_func(*args, **kwargs)
#
#     548 with torch.set_grad_enabled(self._enable_grad):
#
#     549     try:
#
# --> 550         update(*args, **kwargs)
#
#     551     except RuntimeError as err:
#
#     552         if "Expected all tensors to be on" in str(err):
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torchmetrics/classification/precision_recall_curve.py:566, in MultilabelPrecisionRecallCurve.update(self, preds, target)
#
#     562     _multilabel_precision_recall_curve_tensor_validation(preds, target, self.num_labels, self.ignore_index)
#
#     563 preds, target, _ = _multilabel_precision_recall_curve_format(
#
#     564     preds, target, self.num_labels, self.thresholds, self.ignore_index
#
#     565 )
#
# --> 566 state = _multilabel_precision_recall_curve_update(preds, target, self.num_labels, self.thresholds)
#
#     567 if isinstance(state, Tensor):
#
#     568     self.confmat += state
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torchmetrics/functional/classification/precision_recall_curve.py:798, in _multilabel_precision_recall_curve_update(preds, target, num_labels, thresholds)
#
#     796 unique_mapping += 4 * num_labels * torch.arange(len_t, device=preds.device)
#
#     797 unique_mapping = unique_mapping[unique_mapping >= 0]
#
# --> 798 bins = _bincount(unique_mapping, minlength=4 * num_labels * len_t)
#
#     799 return bins.reshape(len_t, num_labels, 2, 2)
#
#
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torchmetrics/utilities/data.py:178, in _bincount(x, minlength)
#
#     174 def _squeeze_if_scalar(data: Any) -> Any:
#
#     175     return apply_to_collection(data, Tensor, _squeeze_scalar_element_tensor)
#
# --> 178 def _bincount(x: Tensor, minlength: Optional[int] = None) -> Tensor:
#
#     179     """Implement custom bincount.
#
#     180
#
#     181     PyTorch currently does not support ``torch.bincount`` when running in deterministic mode on GPU or when running
#
#    (...)
#
#     197
#
#     198     """
#
#     199     if minlength is None:
#
#
#
# KeyboardInterrupt:
