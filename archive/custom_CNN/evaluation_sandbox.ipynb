# %%
import pandas as pd
from opensoundscape.ml.cnn import load_model
import sklearn

# %%
#load model from save path
folder = 'model_9_overlay_updatelabels'
model = load_model(f'/mnt/class_data/group1_bioacoustics/sheila/model_checkpoints/{folder}/best.model')
# Out:
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/opensoundscape/ml/cnn.py:2515: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_content = torch.load(path, map_location=device)
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/opensoundscape/preprocess/overlay.py:98: UserWarning: Overlay class's .overlay_df will be None after loading from dict and `.criterion_fn` will be always_true(). Reset these attributes and set .bypass to False to use Overlay after loading with from_dict().
#   warnings.warn(

# %%
'''#load model from save path
model = load_model('/mnt/class_data/group1_bioacoustics/sheila/model_checkpoints/model_7_overlay/best.model')'''
# Out:
# "#load model from save path\nmodel = load_model('/mnt/class_data/group1_bioacoustics/sheila/model_checkpoints/model_7_overlay/best.model')"

# %%
train_labels = pd.read_csv('data/train_labels.csv',index_col=['file', 'start_time', 'end_time'])
val_labels = pd.read_csv('data/val_labels.csv',index_col=['file', 'start_time', 'end_time'])
test_labels = pd.read_csv('data/test_labels.csv',index_col=['file', 'start_time', 'end_time'])
train_labels.head()
# Out:
#                                                                         Hypsipetes_madagascariensis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                             False
#                                                    2.0        4.0                             False
#                                                    4.0        6.0                             False
#                                                    6.0        8.0                             False
#                                                    8.0        10.0                            False
#
#                                                                         Copsychus_albospecularis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                          False
#                                                    2.0        4.0                          False
#                                                    4.0        6.0                          False
#                                                    6.0        8.0                          False
#                                                    8.0        10.0                         False
#
#                                                                         Coracopsis_nigra  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                  False
#                                                    2.0        4.0                  False
#                                                    4.0        6.0                  False
#                                                    6.0        8.0                  False
#                                                    8.0        10.0                 False
#
#                                                                         Dicrurus_forficatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Coua_caerulea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0               False
#                                                    2.0        4.0               False
#                                                    4.0        6.0               False
#                                                    6.0        8.0               False
#                                                    8.0        10.0              False
#
#                                                                         Zosterops_maderaspatanus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                          False
#                                                    2.0        4.0                          False
#                                                    4.0        6.0                          False
#                                                    6.0        8.0                          False
#                                                    8.0        10.0                         False
#
#                                                                         Eurystomus_glaucurus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                      False
#                                                    2.0        4.0                      False
#                                                    4.0        6.0                      False
#                                                    6.0        8.0                      False
#                                                    8.0        10.0                     False
#
#                                                                         Agapornis_canus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 False
#                                                    2.0        4.0                 False
#                                                    4.0        6.0                 False
#                                                    6.0        8.0                 False
#                                                    8.0        10.0                False
#
#                                                                         Saxicola_torquatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                    False
#                                                    2.0        4.0                    False
#                                                    4.0        6.0                    False
#                                                    6.0        8.0                    False
#                                                    8.0        10.0                   False
#
#                                                                         Cyanolanius_madagascarinus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                            False
#                                                    2.0        4.0                            False
#                                                    4.0        6.0                            False
#                                                    6.0        8.0                            False
#                                                    8.0        10.0                           False
#
#                                                                         Leptopterus_chabert  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Nesoenas_picturatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Coua_reynaudii  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                False
#                                                    2.0        4.0                False
#                                                    4.0        6.0                False
#                                                    6.0        8.0                False
#                                                    8.0        10.0               False
#
#                                                                         Ceblepyris_cinereus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Neodrepanis_coruscans  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                       False
#                                                    2.0        4.0                       False
#                                                    4.0        6.0                       False
#                                                    6.0        8.0                       False
#                                                    8.0        10.0                      False
#
#                                                                         Philepitta_castanea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Eulemur_sp  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0            False
#                                                    2.0        4.0            False
#                                                    4.0        6.0            False
#                                                    6.0        8.0            False
#                                                    8.0        10.0           False
#
#                                                                         Coua_cristata  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0               False
#                                                    2.0        4.0               False
#                                                    4.0        6.0               False
#                                                    6.0        8.0               False
#                                                    8.0        10.0              False
#
#                                                                         Treron_australis
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                
#
#                                                                         Ceblepyris_cinereus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 -4.299631
#                                                    2.0        4.0                 -5.394171
#                                                    4.0        6.0                 -3.485789
#                                                    6.0        8.0                 -4.571709
#                                                    8.0        10.0                -4.038542
#
#                                                                         Neodrepanis_coruscans  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                   -3.431842
#                                                    2.0        4.0                   -4.259420
#                                                    4.0        6.0                   -2.034452
#                                                    6.0        8.0                   -4.175536
#                                                    8.0        10.0                  -4.083615
#
#                                                                         Philepitta_castanea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 -4.453307
#                                                    2.0        4.0                 -6.131381
#                                                    4.0        6.0                 -3.929225
#                                                    6.0        8.0                 -6.042568
#                                                    8.0        10.0                -4.644898
#
#                                                                         Eulemur_sp  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0        -5.618113
#                                                    2.0        4.0        -6.978812
#                                                    4.0        6.0        -6.822177
#                                                    6.0        8.0        -5.640008
#                                                    8.0        10.0       -7.408120
#
#                                                                         Coua_cristata  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0           -6.863846
#                                                    2.0        4.0           -7.483852
#                                                    4.0        6.0           -6.763213
#                                                    6.0        8.0           -6.446471
#                                                    8.0        10.0          -7.112698
#
#                                                                         Treron_australis
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0              -3.634862
#                                                    2.0        4.0              -6.058111
#                                                    4.0        6.0              -7.311429
#                                                    6.0        8.0              -5.878639
#                                                    8.0        10.0             -8.097488

# %%
sklearn.metrics.average_precision_score(val_labels,val_predictions)
# Out:
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 0.40368284695261725

# %%
# Load class list
class_list = ['Hypsipetes_madagascariensis','Copsychus_albospecularis','Coracopsis_nigra','Dicrurus_forficatus','Coua_caerulea','Zosterops_maderaspatanus','Eurystomus_glaucurus','Agapornis_canus','Saxicola_torquatus','Cyanolanius_madagascarinus','Leptopterus_chabert','Nesoenas_picturatus','Coua_reynaudii','Ceblepyris_cinereus','Neodrepanis_coruscans','Philepitta_castanea','Eulemur_sp','Coua_cristata','Treron_australis']
#Double check that it matches training data
class_list==train_labels.columns.values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
sklearn.metrics.roc_auc_score(val_labels['Hypsipetes_madagascariensis'],val_predictions ['Hypsipetes_madagascariensis'])
# Out:
# 0.931048617051611

# %%
avprecscore_auroc_by_sp = pd.DataFrame(columns=['species', 'avg_precision_score_val','auroc_score_val', 'avg_precision_score_train','auroc_score_train'])
for species in class_list:
    avgscore_val = sklearn.metrics.average_precision_score(val_labels [species],val_predictions [species])
    auroc_val = sklearn.metrics.roc_auc_score(val_labels[species],val_predictions [species])
    avgscore_train = sklearn.metrics.average_precision_score(train_labels [species],train_predictions [species])
    auroc_train = sklearn.metrics.roc_auc_score(train_labels[species],train_predictions [species])
    new_row = pd.DataFrame({'species': [species], 'avg_precision_score_val': [avgscore_val], 'auroc_score_val': [auroc_val], 'avg_precision_score_train': [avgscore_train], 'auroc_score_train': [auroc_train]})
    avprecscore_auroc_by_sp = pd.concat([avprecscore_auroc_by_sp, new_row], ignore_index=True)

avprecscore_auroc_by_sp
# Out:
# /tmp/ipykernel_409692/478757880.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   avprecscore_auroc_by_sp = pd.concat([avprecscore_auroc_by_sp, new_row], ignore_index=True)
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#                         species  avg_precision_score_val  auroc_score_val  \
# 0   Hypsipetes_madagascariensis                 0.845862         0.931049
# 1      Copsychus_albospecularis                 0.673631         0.976682
# 2              Coracopsis_nigra                 0.675441         0.977629
# 3           Dicrurus_forficatus                 0.676775         0.954822
# 4                 Coua_caerulea                 0.637995         0.987208
# 5      Zosterops_maderaspatanus                 0.191920         0.953962
# 6          Eurystomus_glaucurus                 0.884086         0.997262
# 7               Agapornis_canus                 0.603469         0.991793
# 8            Saxicola_torquatus                 0.698536         0.994019
# 9    Cyanolanius_madagascarinus                 0.327786         0.963039
# 10          Leptopterus_chabert                 0.376998         0.867042
# 11          Nesoenas_picturatus                 0.000000              NaN
# 12               Coua_reynaudii                 0.000000              NaN
# 13          Ceblepyris_cinereus                 0.004887         0.912961
# 14        Neodrepanis_coruscans                 0.966667         0.999946
# 15          Philepitta_castanea                 0.001787         0.218995
# 16                   Eulemur_sp                 0.103118         0.928649
# 17                Coua_cristata                 0.000000              NaN
# 18             Treron_australis                 0.001017         0.428688
#
#     avg_precision_score_train  auroc_score_train
# 0                    0.869359           0.957898
# 1                    0.726814           0.961667
# 2                    0.709439           0.979306
# 3                    0.796666           0.974467
# 4                    0.803198           0.996206
# 5                    0.763137           0.989670
# 6                    0.821518           0.990638
# 7                    0.572670           0.985571
# 8                    0.872380           0.998963
# 9                    0.664751           0.975559
# 10                   0.793873           0.994234
# 11                   0.833499           0.999241
# 12                   0.863871           0.999132
# 13                   0.842259           0.996428
# 14                   0.693242           0.996162
# 15                   0.924325           0.999892
# 16                   0.445732           0.994711
# 17                   1.000000           1.000000
# 18                   0.663660           0.999438

# %%
avprecscore_auroc_by_sp.to_csv(f'/mnt/class_data/group1_bioacoustics/sheila/results/{folder}.csv')

# %%
#Choose a species to look at
samples = val_labels[val_labels['Coua_caerulea']]

# %%
#visualize the species
from opensoundscape.preprocess.utils import show_tensor_grid
from opensoundscape import AudioFileDataset
'''pre = SpectrogramPreprocessor(sample_duration=2.0)'''
dataset = AudioFileDataset(samples,model.preprocessor)
dataset.bypass_augmentations = True


tensors = [dataset[i].data for i in range(9)]
sample_labels = [list(dataset[i].labels[dataset[i].labels>0].index) for i in range(9)]

_ = show_tensor_grid(tensors,3,labels=sample_labels)

# %%
val_labels.head()
# Out:
#                                                                         Hypsipetes_madagascariensis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                             False
#                                                    2.0        4.0                             False
#                                                    4.0        6.0                             False
#                                                    6.0        8.0                             False
#                                                    8.0        10.0                            False
#
#                                                                         Copsychus_albospecularis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                          False
#                                                    2.0        4.0                          False
#                                                    4.0        6.0                          False
#                                                    6.0        8.0                          False
#                                                    8.0        10.0                         False
#
#                                                                         Coracopsis_nigra  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                  False
#                                                    2.0        4.0                  False
#                                                    4.0        6.0                  False
#                                                    6.0        8.0                  False
#                                                    8.0        10.0                 False
#
#                                                                         Dicrurus_forficatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Coua_caerulea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0               False
#                                                    2.0        4.0               False
#                                                    4.0        6.0               False
#                                                    6.0        8.0               False
#                                                    8.0        10.0              False
#
#                                                                         Zosterops_maderaspatanus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                          False
#                                                    2.0        4.0                          False
#                                                    4.0        6.0                          False
#                                                    6.0        8.0                          False
#                                                    8.0        10.0                         False
#
#                                                                         Eurystomus_glaucurus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                      False
#                                                    2.0        4.0                      False
#                                                    4.0        6.0                      False
#                                                    6.0        8.0                      False
#                                                    8.0        10.0                     False
#
#                                                                         Agapornis_canus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 False
#                                                    2.0        4.0                 False
#                                                    4.0        6.0                 False
#                                                    6.0        8.0                 False
#                                                    8.0        10.0                False
#
#                                                                         Saxicola_torquatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                    False
#                                                    2.0        4.0                    False
#                                                    4.0        6.0                    False
#                                                    6.0        8.0                    False
#                                                    8.0        10.0                   False
#
#                                                                         Cyanolanius_madagascarinus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                            False
#                                                    2.0        4.0                            False
#                                                    4.0        6.0                            False
#                                                    6.0        8.0                            False
#                                                    8.0        10.0                           False
#
#                                                                         Leptopterus_chabert  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Nesoenas_picturatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Coua_reynaudii  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                False
#                                                    2.0        4.0                False
#                                                    4.0        6.0                False
#                                                    6.0        8.0                False
#                                                    8.0        10.0               False
#
#                                                                         Ceblepyris_cinereus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Neodrepanis_coruscans  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                       False
#                                                    2.0        4.0                       False
#                                                    4.0        6.0                       False
#                                                    6.0        8.0                       False
#                                                    8.0        10.0                      False
#
#                                                                         Philepitta_castanea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                      True
#                                                    2.0        4.0                      True
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                      True
#                                                    8.0        10.0                     True
#
#                                                                         Eulemur_sp  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0            False
#                                                    2.0        4.0            False
#                                                    4.0        6.0            False
#                                                    6.0        8.0            False
#                                                    8.0        10.0           False
#
#                                                                         Coua_cristata  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0               False
#                                                    2.0        4.0               False
#                                                    4.0        6.0               False
#                                                    6.0        8.0               False
#                                                    8.0        10.0              False
#
#                                                                         Treron_australis
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                  False
#                                                    2.0        4.0                  False
#                                                    4.0        6.0                  False
#                                                    6.0        8.0                  False
#                                                    8.0        10.0                 False

# %%
#Look specifically at spectrograms for TRUE that were scored high and low and for FALSE that were scored high and low. Use val_labels and val_predictions. 
val_positive_scores = val_predictions[val_labels]
val_positive_scores.head()
# Out:
#                                                                         Hypsipetes_madagascariensis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                               NaN
#                                                    2.0        4.0                               NaN
#                                                    4.0        6.0                               NaN
#                                                    6.0        8.0                               NaN
#                                                    8.0        10.0                              NaN
#
#                                                                         Copsychus_albospecularis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                            NaN
#                                                    2.0        4.0                            NaN
#                                                    4.0        6.0                            NaN
#                                                    6.0        8.0                            NaN
#                                                    8.0        10.0                           NaN
#
#                                                                         Coracopsis_nigra  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                    NaN
#                                                    2.0        4.0                    NaN
#                                                    4.0        6.0                    NaN
#                                                    6.0        8.0                    NaN
#                                                    8.0        10.0                   NaN
#
#                                                                         Dicrurus_forficatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                       NaN
#                                                    2.0        4.0                       NaN
#                                                    4.0        6.0                       NaN
#                                                    6.0        8.0                       NaN
#                                                    8.0        10.0                      NaN
#
#                                                                         Coua_caerulea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 NaN
#                                                    2.0        4.0                 NaN
#                                                    4.0        6.0                 NaN
#                                                    6.0        8.0                 NaN
#                                                    8.0        10.0                NaN
#
#                                                                         Zosterops_maderaspatanus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                            NaN
#                                                    2.0        4.0                            NaN
#                                                    4.0        6.0                            NaN
#                                                    6.0        8.0                            NaN
#                                                    8.0        10.0                           NaN
#
#                                                                         Eurystomus_glaucurus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                        NaN
#                                                    2.0        4.0                        NaN
#                                                    4.0        6.0                        NaN
#                                                    6.0        8.0                        NaN
#                                                    8.0        10.0                       NaN
#
#                                                                         Agapornis_canus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                   NaN
#                                                    2.0        4.0                   NaN
#                                                    4.0        6.0                   NaN
#                                                    6.0        8.0                   NaN
#                                                    8.0        10.0                  NaN
#
#                                                                         Saxicola_torquatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                      NaN
#                                                    2.0        4.0                      NaN
#                                                    4.0        6.0                      NaN
#                                                    6.0        8.0                      NaN
#                                                    8.0        10.0                     NaN
#
#                                                                         Cyanolanius_madagascarinus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                              NaN
#                                                    2.0        4.0                              NaN
#                                                    4.0        6.0                              NaN
#                                                    6.0        8.0                              NaN
#                                                    8.0        10.0                             NaN
#
#                                                                         Leptopterus_chabert  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                       NaN
#                                                    2.0        4.0                       NaN
#                                                    4.0        6.0                       NaN
#                                                    6.0        8.0                       NaN
#                                                    8.0        10.0                      NaN
#
#                                                                         Nesoenas_picturatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                
#
#                                                                         Cyanolanius_madagascarinus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                        -6.801025
#                                                    2.0        4.0                        -6.738030
#                                                    4.0        6.0                        -6.212946
#                                                    6.0        8.0                        -8.094068
#                                                    8.0        10.0                       -6.371550
#
#                                                                         Leptopterus_chabert  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 -6.874735
#                                                    2.0        4.0                 -7.344070
#                                                    4.0        6.0                 -5.740145
#                                                    6.0        8.0                 -6.216996
#                                                    8.0        10.0                -7.371336
#
#                                                                         Nesoenas_picturatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 -6.946675
#                                                    2.0        4.0                 -8.196335
#                                                    4.0        6.0                 -6.702850
#                                                    6.0        8.0                 -5.546800
#                                                    8.0        10.0                -6.738272
#
#                                                                         Coua_reynaudii  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0            -6.331829
#                                                    2.0        4.0            -6.461633
#                                                    4.0        6.0            -6.121953
#                                                    6.0        8.0            -5.965058
#                                                    8.0        10.0           -5.104681
#
#                                                                         Ceblepyris_cinereus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 -7.107512
#                                                    2.0        4.0                 -6.497910
#                                                    4.0        6.0                 -6.019481
#                                                    6.0        8.0                 -5.443567
#                                                    8.0        10.0                -7.016075
#
#                                                                         Neodrepanis_coruscans  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                   -2.253963
#                                                    2.0        4.0                    1.199007
#                                                    4.0        6.0                    0.534412
#                                                    6.0        8.0                   -0.202273
#                                                    8.0        10.0                  -1.317255
#
#                                                                         Philepitta_castanea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                       NaN
#                                                    2.0        4.0                       NaN
#                                                    4.0        6.0                 -6.790773
#                                                    6.0        8.0                       NaN
#                                                    8.0        10.0                      NaN
#
#                                                                         Eulemur_sp  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0        -1.374761
#                                                    2.0        4.0        -3.365244
#                                                    4.0        6.0        -2.940209
#                                                    6.0        8.0        -4.321431
#                                                    8.0        10.0       -1.543895
#
#                                                                         Coua_cristata  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0           -7.671036
#                                                    2.0        4.0           -8.047597
#                                                    4.0        6.0           -7.762614
#                                                    6.0        8.0           -7.756769
#                                                    8.0        10.0          -7.409977
#
#                                                                         Treron_australis
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0              -5.840008
#                                                    2.0        4.0              -5.939957
#                                                    4.0        6.0              -5.542247
#                                                    6.0        8.0              -6.073810
#                                                    8.0        10.0             -6.225170

# %%
sorted_column = val_positive_scores['Hypsipetes_madagascariensis'].sort_values()
print(sorted_column)
# Out:
# file                                                                                                                                           start_time  end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Marojejy/MAR_A/MAR_A-MAR10/MAR_A-MAR10_20230519_092000.WAV                  20.0        22.0       -5.379862
#                                                                                                                                                14.0        16.0       -5.169207
# /mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Marojejy/AGR_A/AGR_A-AGR04/AGR_A-AGR04_20230509_080000.WAV                  26.0        28.0       -4.747817
# /mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Analalava/NLR_A/NLR_A-NLR02/NLR_A-NLR02_20230209_102000.WAV                 4.0         6.0        -4.147989
# /mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Ankarabolava_Agnakatrika/NBR_A/NBR_A-NBR09/NBR_A-NBR09_20230724_062000.WAV  52.0        54.0       -3.929928
#                                                                                                                                                                          ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Analalava/NLR_B/NLR_B-NLR02/NLR_B-NLR02_20230209_081000.WAV                 52.0        54.0             NaN
#                                                                                                                                                54.0        56.0             NaN
#                                                                                                                                                56.0        58.0             NaN
#                                                                                                                                                58.0        60.0             NaN
# /mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Analalava/NLR_B/NLR_B-NLR02/NLR_B-NLR02_20230209_141000.WAV                 26.0        28.0             NaN
# Name: Hypsipetes_madagascariensis, Length: 3690, dtype: float32

# %%
val_positive_scores.to_csv(f'/mnt/class_data/group1_bioacoustics/sheila/results/{folder}_val_positive_scores.csv')
val_negative_scores.to_csv(f'/mnt/class_data/group1_bioacoustics/sheila/results/{folder}_val_negative_scores.csv')

# %%
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
#write a loop to cycle through the class list and save histograms for each species for the model read in at the top of this notebook
path = '/mnt/class_data/group1_bioacoustics/sheila/histograms'
for species in class_list:
    speciespred = species + 'pred'
    scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
    # Filter
    df_Pos = scores_valid_df[scores_valid_df[species] == True] #or whatever your class of interest is called
    df_NOT = scores_valid_df[scores_valid_df[species] == False]
    # Plot histograms
    plt.hist(df_NOT[speciespred],bins=20,alpha=0.5,label='negatives')
    plt.hist(df_Pos[speciespred],bins=20,alpha=0.5,label='positives')
    # Add a legend and labels
    plt.legend()
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    # Save the plot
    plt.savefig(f'/mnt/class_data/group1_bioacoustics/sheila/histograms/{folder}_{species}.png')
    plt.clf()
# Out:
# /home/Sheila/miniconda3/envs/rewilding_cv4e/lib/python3.10/site-packages/matplotlib_inline/config.py:68: DeprecationWarning: InlineBackend._figure_format_changed is deprecated in traitlets 4.1: use @observe and @unobserve instead.
#   def _figure_format_changed(self, name, old, new):

# %%
#Histogram with Y axis on log scale
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
#write a loop to cycle through the class list and save histograms for each species for the model read in at the top of this notebook
path = '/mnt/class_data/group1_bioacoustics/sheila/histograms'
for species in class_list:
    speciespred = species + 'pred'
    scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
    # Filter
    df_Pos = scores_valid_df[scores_valid_df[species] == True] #or whatever your class of interest is called
    df_NOT = scores_valid_df[scores_valid_df[species] == False]
    # Plot histograms
    plt.hist(df_NOT[speciespred],bins=20,alpha=0.5,label='negatives')
    plt.hist(df_Pos[speciespred],bins=20,alpha=0.5,label='positives')
    # Add a legend and labels
    plt.legend()
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    plt.semilogy()
    # Save the plot
    plt.savefig(f'/mnt/class_data/group1_bioacoustics/sheila/histograms/semilog/{folder}_{species}.png')
    plt.clf()

# %%
histspecies = 'Hypsipetes_madagascariensis'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Copsychus_albospecularis'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Coracopsis_nigra'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Dicrurus_forficatus'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Coua_caerulea'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Zosterops_maderaspatanus'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Eurystomus_glaucurus'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Agapornis_canus'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Saxicola_torquatus'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Cyanolanius_madagascarinus'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Leptopterus_chabert'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Nesoenas_picturatus'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Coua_reynaudii'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Ceblepyris_cinereus'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Neodrepanis_coruscans'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Philepitta_castanea'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
histspecies = 'Eulemur_sp'
histspeciespred = histspecies + 'pred'
#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'
# read in the best model - done earlier
# extract raw scores from the model
# merge labels into scores
scores_valid_df = val_labels.join(val_predictions, rsuffix="pred")
# Filter
df_Pos = scores_valid_df[scores_valid_df[histspecies] == True] #or whatever your class of interest is called
df_NOT = scores_valid_df[scores_valid_df[histspecies] == False]
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#Histogram with Y axis on log scale
# Plot histograms
plt.hist(df_NOT[histspeciespred],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspeciespred],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()
