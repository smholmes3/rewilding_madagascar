# %%
import torch
import pandas as pd
from pathlib import Path
import numpy as np
import pandas as pd
import random
from glob import glob
import sklearn

from tqdm.autonotebook import tqdm
from sklearn.metrics import average_precision_score, roc_auc_score
from pathlib import Path

#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'

# opensoundscape transfer learning tools
from opensoundscape.ml.shallow_classifier import MLPClassifier, quick_fit, fit_classifier_on_embeddings
# Out:
# /tmp/ipykernel_370553/121805284.py:10: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from sklearn.model_selection import train_test_split
from opensoundscape import BoxedAnnotations, CNN
import opensoundscape

# %%
n_samples_per_class = 5221
filename = 'Shallow_classifier_perch_resample_full'

# %%
metadata = pd.read_csv('./data/metadata.csv')
metadata.head()
# Out:
#    Unnamed: 0  Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0           0        0.763354      3.078034       2854.369        5965.410
# 1           1        6.588949      9.475884       2571.297        5451.150
# 2           2       10.434780     12.523959       3085.557        5348.299
# 3           3       14.854197     15.436757       3085.557        5862.558
# 4           4       55.578030     59.479764       2621.359        5475.728
#
#                Species  Conf Call_type                         Filename  \
# 0  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 1  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 2  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 3  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 4  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
#
#   SiteHab RecordingSched RecorderName     DP                        SoundFile  \
# 0     AGN              A  AGN_A-AGN04  AGN04  AGN_A-AGN04_20230429_054000.WAV
# 1     AGN              A  AGN_A-AGN04  AGN04  AGN_A-AGN04_20230429_054000.WAV
# 2     AGN              A  AGN_A-AGN04  AGN04  AGN_A-AGN04_20230429_054000.WAV
# 3     AGN              A  AGN_A-AGN04  AGN04  AGN_A-AGN04_20230429_054000.WAV
# 4     AGN              A  AGN_A-AGN04  AGN04  AGN_A-AGN04_20230429_054000.WAV
#
#                                       SoundFile_path       Split  \
# 0  /mnt/class_data/group1_bioacoustics/sheila/cv4...  validation
# 1  /mnt/class_data/group1_bioacoustics/sheila/cv4...  validation
# 2  /mnt/class_data/group1_bioacoustics/sheila/cv4...  validation
# 3  /mnt/class_data/group1_bioacoustics/sheila/cv4...  validation
# 4  /mnt/class_data/group1_bioacoustics/sheila/cv4...  validation
#
#                                           Raven_path
# 0  /mnt/class_data/group1_bioacoustics/sheila/Pro...
# 1  /mnt/class_data/group1_bioacoustics/sheila/Pro...
# 2  /mnt/class_data/group1_bioacoustics/sheila/Pro...
# 3  /mnt/class_data/group1_bioacoustics/sheila/Pro...
# 4  /mnt/class_data/group1_bioacoustics/sheila/Pro...

# %%
val_metadata=metadata[metadata["Split"]=="validation"]
train_metadata=metadata[metadata["Split"]=="train"]
test_metadata=metadata[metadata["Split"]=="test"]

# %%
val_metadata=val_metadata.reset_index()
train_metadata=train_metadata.reset_index()
test_metadata=test_metadata.reset_index()

# %%
# assume we have a list of raven annotation files and corresponding audio files
# load the annotations into OpenSoundscape
raven_file_paths = val_metadata['Raven_path']
audio_file_paths = val_metadata['SoundFile_path']
val_annotations = BoxedAnnotations.from_raven_files(raven_file_paths,'species',audio_file_paths)

raven_file_paths = train_metadata['Raven_path']
audio_file_paths = train_metadata['SoundFile_path']
train_annotations = BoxedAnnotations.from_raven_files(raven_file_paths,'species',audio_file_paths)

raven_file_paths = test_metadata['Raven_path']
audio_file_paths = test_metadata['SoundFile_path']
test_annotations = BoxedAnnotations.from_raven_files(raven_file_paths,'species',audio_file_paths)

# %%
# Create the table with a dataframe
conversion_table = pd.DataFrame(
    {'original':['Eulemur_albifrons', 'Eulemur_fulvus'],
     'new':['Eulemur_sp', 'Eulemur_sp']}
)

# Or create the table in its own spreadsheet
#conversion_table = pd.read_csv('my_conversion_filename_here.csv')

conversion_table
# Out:
#             original         new
# 0  Eulemur_albifrons  Eulemur_sp
# 1     Eulemur_fulvus  Eulemur_sp

# %%
#correct annotations in each of the splits
val_annotations_corrected = val_annotations.convert_labels(conversion_table)
val_annotations_corrected.audio_files = val_annotations_corrected.df['audio_file'].values #workaround for issue #872
val_annotations_corrected.df.head()

train_annotations_corrected = train_annotations.convert_labels(conversion_table)
train_annotations_corrected.audio_files = train_annotations_corrected.df['audio_file'].values #workaround for issue #872
train_annotations_corrected.df.head()

test_annotations_corrected = test_annotations.convert_labels(conversion_table)
test_annotations_corrected.audio_files = test_annotations_corrected.df['audio_file'].values #workaround for issue #872
test_annotations_corrected.df.head()
# Out:
#                                           audio_file  \
# 0  /mnt/class_data/group1_bioacoustics/sheila/cv4...
# 1  /mnt/class_data/group1_bioacoustics/sheila/cv4...
# 2  /mnt/class_data/group1_bioacoustics/sheila/cv4...
# 3  /mnt/class_data/group1_bioacoustics/sheila/cv4...
# 4  /mnt/class_data/group1_bioacoustics/sheila/cv4...
#
#                                      annotation_file  \
# 0  /mnt/class_data/group1_bioacoustics/sheila/Pro...
# 1  /mnt/class_data/group1_bioacoustics/sheila/Pro...
# 2  /mnt/class_data/group1_bioacoustics/sheila/Pro...
# 3  /mnt/class_data/group1_bioacoustics/sheila/Pro...
# 4  /mnt/class_data/group1_bioacoustics/sheila/Pro...
#
#                     annotation  start_time   end_time     low_f    high_f  \
# 0  Hypsipetes_madagascariensis   54.905264  56.190913  1968.454  5223.975
# 1          Dicrurus_forficatus    4.943181  11.329778   659.794  5690.722
# 2          Dicrurus_forficatus   13.011363  15.447871   551.700  5773.196
# 3          Dicrurus_forficatus   17.215908  19.923388   494.845  5773.196
# 4          Dicrurus_forficatus   24.282540  29.043458   742.268  6103.093
#
#    Delta Freq (Hz)  Avg Power Density (dB FS/Hz)  Channel  Conf  Selection  \
# 0              NaN                           NaN        1   0.9          1
# 1              NaN                           NaN        1   0.9          1
# 2              NaN                           NaN        1   0.9          2
# 3              NaN                           NaN        1   0.9          3
# 4              NaN                           NaN        1   0.9          4
#
#   Call_type           View  Delta Time (s)
# 0      call  Spectrogram 1             NaN
# 1      call  Spectrogram 1             NaN
# 2      call  Spectrogram 1             NaN
# 3      call  Spectrogram 1             NaN
# 4      call  Spectrogram 1             NaN

# %%
# pick classes to train the model on. These should occur in the annotated data
class_list = ['Hypsipetes_madagascariensis','Copsychus_albospecularis','Coracopsis_nigra','Dicrurus_forficatus','Coua_caerulea','Zosterops_maderaspatanus','Eurystomus_glaucurus','Agapornis_canus','Saxicola_torquatus','Cyanolanius_madagascarinus','Leptopterus_chabert','Nesoenas_picturatus','Coua_reynaudii','Ceblepyris_cinereus','Neodrepanis_coruscans','Philepitta_castanea','Eulemur_sp','Coua_cristata','Treron_australis']

# %%
# create labels for fixed-duration (5 second) clips
val_labels = val_annotations_corrected.clip_labels(
  clip_duration=5,
  clip_overlap=0,
  min_label_overlap=0.25,
  class_subset=class_list
)

train_labels = train_annotations_corrected.clip_labels(
  clip_duration=5,
  clip_overlap=0,
  min_label_overlap=0.25,
  class_subset=class_list
)

test_labels = test_annotations_corrected.clip_labels(
  clip_duration=5,
  clip_overlap=0,
  min_label_overlap=0.25,
  class_subset=class_list
)

# %%
train_labels_resampled = opensoundscape.data_selection.resample(train_labels,n_samples_per_class = n_samples_per_class, downsample = False,upsample = True)

# %%
from bioacoustics_model_zoo import Perch

# %%
perch_model = Perch()
# Out:
# 2025-01-22 23:14:51.417503: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-22 23:14:51.417544: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-22 23:14:51.418496: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-22 23:14:51.423470: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-22 23:14:53.111314: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.114772: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.116841: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.122032: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.124101: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.126174: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.292244: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.293691: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.294995: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-22 23:14:53.296246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38380 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:04:00.0, compute capability: 8.0
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/opensoundscape/ml/cnn.py:621: UserWarning:
#                     This architecture is not listed in opensoundscape.ml.cnn_architectures.ARCH_DICT.
#                     It will not be available for loading after saving the model with .save() (unless using pickle=True).
#                     To make it re-loadable, define a function that generates the architecture from arguments: (n_classes, n_channels)
#                     then use opensoundscape.ml.cnn_architectures.register_architecture() to register the generating function.
#
#                     The function can also set the returned object's .constructor_name to the registered string key in ARCH_DICT
#                     to avoid this warning and ensure it is reloaded correctly by opensoundscape.ml.load_model().
#
#                     See opensoundscape.ml.cnn_architectures module for examples of constructor functions
#
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/opensoundscape/ml/cnn.py:645: UserWarning: Failed to detect expected # input channels of this architecture.Make sure your architecture expects the number of channels equal to `channels` argument 1). Pytorch architectures generally expect 3 channels by default.
#   warnings.warn(

# %%
emb_train = perch_model.embed(train_labels_resampled, return_dfs=False, batch_size=128, num_workers=0)
emb_val = perch_model.embed(val_labels, return_dfs=False, batch_size=128, num_workers=0)
# Out:
#   0%|          | 0/775 [00:00<?, ?it/s]
# 2025-01-22 23:14:59.059612: I external/local_xla/xla/service/service.cc:168] XLA service 0x641a4d9fa160 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-01-22 23:14:59.059659: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2025-01-22 23:14:59.303005: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-01-22 23:14:59.311158: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:38] Ignoring Assert operator jax2tf_infer_fn_/assert_equal_1/Assert/AssertGuard/Assert
# 2025-01-22 23:14:59.891075: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-01-22 23:15:02.930825: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[128,160,500,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,160,755,1]{3,2,1,0}, f32[160,1,256,1]{3,2,1,0}), window={size=256x1}, dim_labels=bf01_oi01->bf01, feature_group_count=160, custom_call_target="__cudnn$convForward", backend_config={"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2025-01-22 23:15:04.293865: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.363229925s
# Trying algorithm eng4{} for conv (f32[128,160,500,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,160,755,1]{3,2,1,0}, f32[160,1,256,1]{3,2,1,0}), window={size=256x1}, dim_labels=bf01_oi01->bf01, feature_group_count=160, custom_call_target="__cudnn$convForward", backend_config={"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2025-01-22 23:15:05.377466: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[128,160,500,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,160,755,1]{3,2,1,0}, f32[160,1,256,1]{3,2,1,0}), window={size=256x1}, dim_labels=bf01_oi01->bf01, feature_group_count=160, custom_call_target="__cudnn$convForward", backend_config={"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2025-01-22 23:15:06.744712: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.367364922s
# Trying algorithm eng4{} for conv (f32[128,160,500,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,160,755,1]{3,2,1,0}, f32[160,1,256,1]{3,2,1,0}), window={size=256x1}, dim_labels=bf01_oi01->bf01, feature_group_count=160, custom_call_target="__cudnn$convForward", backend_config={"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737587721.424466  370553 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-01-22 23:32:05.457344: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:38] Ignoring Assert operator jax2tf_infer_fn_/assert_equal_1/Assert/AssertGuard/Assert
# 2025-01-22 23:32:08.841863: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[127,160,500,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[127,160,755,1]{3,2,1,0}, f32[160,1,256,1]{3,2,1,0}), window={size=256x1}, dim_labels=bf01_oi01->bf01, feature_group_count=160, custom_call_target="__cudnn$convForward", backend_config={"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2025-01-22 23:32:10.217426: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.375733606s
# Trying algorithm eng4{} for conv (f32[127,160,500,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[127,160,755,1]{3,2,1,0}, f32[160,1,256,1]{3,2,1,0}), window={size=256x1}, dim_labels=bf01_oi01->bf01, feature_group_count=160, custom_call_target="__cudnn$convForward", backend_config={"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2025-01-22 23:32:11.300553: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[127,160,500,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[127,160,755,1]{3,2,1,0}, f32[160,1,256,1]{3,2,1,0}), window={size=256x1}, dim_labels=bf01_oi01->bf01, feature_group_count=160, custom_call_target="__cudnn$convForward", backend_config={"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2025-01-22 23:32:12.682511: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.382077938s
# Trying algorithm eng4{} for conv (f32[127,160,500,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[127,160,755,1]{3,2,1,0}, f32[160,1,256,1]{3,2,1,0}), window={size=256x1}, dim_labels=bf01_oi01->bf01, feature_group_count=160, custom_call_target="__cudnn$convForward", backend_config={"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
#   0%|          | 0/12 [00:00<?, ?it/s]
# 2025-01-22 23:32:47.852594: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:38] Ignoring Assert operator jax2tf_infer_fn_/assert_equal_1/Assert/AssertGuard/Assert

# %%
# pick classes to train the model on. These should occur in the annotated data
class_list = ['Hypsipetes_madagascariensis','Copsychus_albospecularis','Coracopsis_nigra','Dicrurus_forficatus','Coua_caerulea','Zosterops_maderaspatanus','Eurystomus_glaucurus','Agapornis_canus','Saxicola_torquatus','Cyanolanius_madagascarinus','Leptopterus_chabert','Nesoenas_picturatus','Coua_reynaudii','Ceblepyris_cinereus','Neodrepanis_coruscans','Philepitta_castanea','Eulemur_sp','Coua_cristata','Treron_australis']

# %%
perch_model.change_classes(class_list) # replace fc layer with 1-output layer
quick_fit(perch_model.network, emb_train, train_labels_resampled.values, emb_val, val_labels.values,steps=1000)
# Out:
# Epoch 100/1000, Loss: 0.18424038589000702, Val Loss: 0.16099761426448822
# val AU ROC: 0.283
# val MAP: 0.283
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 200/1000, Loss: 0.11800569295883179, Val Loss: 0.1117333248257637
# val AU ROC: 0.442
# val MAP: 0.442
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 300/1000, Loss: 0.08599314838647842, Val Loss: 0.09120684117078781
# val AU ROC: 0.479
# val MAP: 0.479
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 400/1000, Loss: 0.0674748346209526, Val Loss: 0.07945583760738373
# val AU ROC: 0.490
# val MAP: 0.490
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 500/1000, Loss: 0.05550675094127655, Val Loss: 0.07192137837409973
# val AU ROC: 0.492
# val MAP: 0.492
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 600/1000, Loss: 0.04713115468621254, Val Loss: 0.06673095375299454
# val AU ROC: 0.493
# val MAP: 0.493
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 700/1000, Loss: 0.0409211702644825, Val Loss: 0.06296616047620773
# val AU ROC: 0.492
# val MAP: 0.492
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 800/1000, Loss: 0.036117419600486755, Val Loss: 0.060130130499601364
# val AU ROC: 0.490
# val MAP: 0.490
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 900/1000, Loss: 0.03228289261460304, Val Loss: 0.05793129652738571
# val AU ROC: 0.491
# val MAP: 0.491
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Epoch 1000/1000, Loss: 0.029147757217288017, Val Loss: 0.05618828535079956
# val AU ROC: 0.493
# val MAP: 0.493
# Training complete
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
val_labels
# Out:
#                                                                         Hypsipetes_madagascariensis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                             False
#                                                    5.0        10.0                            False
#                                                    10.0       15.0                            False
#                                                    15.0       20.0                            False
#                                                    20.0       25.0                            False
# ...                                                                                             ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                             True
#                                                    40.0       45.0                             True
#                                                    45.0       50.0                             True
#                                                    50.0       55.0                             True
#                                                    55.0       60.0                             True
#
#                                                                         Copsychus_albospecularis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                          False
#                                                    5.0        10.0                         False
#                                                    10.0       15.0                         False
#                                                    15.0       20.0                         False
#                                                    20.0       25.0                         False
# ...                                                                                          ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                         False
#                                                    40.0       45.0                         False
#                                                    45.0       50.0                         False
#                                                    50.0       55.0                         False
#                                                    55.0       60.0                         False
#
#                                                                         Coracopsis_nigra  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                  False
#                                                    5.0        10.0                 False
#                                                    10.0       15.0                 False
#                                                    15.0       20.0                 False
#                                                    20.0       25.0                 False
# ...                                                                                  ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                 False
#                                                    40.0       45.0                 False
#                                                    45.0       50.0                 False
#                                                    50.0       55.0                 False
#                                                    55.0       60.0                 False
#
#                                                                         Dicrurus_forficatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                     False
#                                                    5.0        10.0                    False
#                                                    10.0       15.0                    False
#                                                    15.0       20.0                    False
#                                                    20.0       25.0                    False
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                    False
#                                                    40.0       45.0                    False
#                                                    45.0       50.0                    False
#                                                    50.0       55.0                    False
#                                                    55.0       60.0                    False
#
#                                                                         Coua_caerulea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0               False
#                                                    5.0        10.0              False
#                                                    10.0       15.0              False
#                                                    15.0       20.0              False
#                                                    20.0       25.0              False
# ...                                                                               ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0              False
#                                                    40.0       45.0              False
#                                                    45.0       50.0              False
#                                                    50.0       55.0              False
#                                                    55.0       60.0              False
#
#                                                                         Zosterops_maderaspatanus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                          False
#                                                    5.0        10.0                         False
#                                                    10.0       15.0                         False
#                                                    15.0       20.0                         False
#                                                    20.0       25.0                         False
# ...                                                                                          ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                         False
#                                                    40.0       45.0                         False
#                                                    45.0       50.0                         False
#                                                    50.0       55.0                         False
#                                                    55.0       60.0                         False
#
#                                                                         Eurystomus_glaucurus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                      False
#                                                    5.0        10.0                     False
#                                                    10.0       15.0                     False
#                                                    15.0       20.0                     False
#                                                    20.0       25.0                     False
# ...                                                                                      ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                     False
#                                                    40.0       45.0                     False
#                                                    45.0       50.0                     False
#                                                    50.0       55.0                     False
#                                                    55.0       60.0                     False
#
#                                                                         Agapornis_canus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                 False
#                                                    5.0        10.0                False
#                                                    10.0       15.0                False
#                                                    15.0       20.0                False
#                                                    20.0       25.0                False
# ...                                                                                 ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                False
#                                                    40.0       45.0                False
#                                                    45.0       50.0                False
#                                                    50.0       55.0                False
#                                                    55.0       60.0                False
#
#                                                                         Saxicola_torquatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                    False
#                                                    5.0        10.0                   False
#                                                    10.0       15.0                   False
#                                                    15.0       20.0                   False
#                                                    20.0       25.0                   False
# ...                                                                                    ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                   False
#                                                    40.0       45.0                   False
#                                                    45.0       50.0                   False
#                                                    50.0       55.0                   False
#                                                    55.0       60.0                   False
#
#                                                                         Cyanolanius_madagascarinus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                            False
#                                                    5.0        10.0                           False
#                                                    10.0       15.0                           False
#                                                    15.0       20.0                           False
#                                                    20.0       25.0                           False
# ...                                                                                            ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                           False
#                                                    40.0       45.0                           False
#                                                    45.0       50.0                           False
#                                                    50.0       55.0                           False
#                                                    55.0       60.0                           False
#
#                                                                         Leptopterus_chabert  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                     False
#                                                    5.0        10.0                    False
#                                                    10.0       15.0                    False
#                                                    15.0       20.0                    False
#                                                    20.0       25.0                    False
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                    False
#                                                    40.0       45.0                    False
#                                                    45.0       50.0                    False
#                                                    50.0       55.0                    False
#                                                    55.0       60.0                    False
#
#                                                                         Nesoenas_picturatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                     False
#                                                    5.0        10.0                    False
#                                                    10.0       15.0                    False
#                                                    15.0       20.0                    False
#                                                    20.0       25.0                    False
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                    False
#                                                    40.0       45.0                    False
#                                                    45.0       50.0                    False
#                                                    50.0       55.0                    False
#                                                    55.0       60.0                    False
#
#                                                                         Coua_reynaudii  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                False
#                                                    5.0        10.0               False
#                                                    10.0       15.0               False
#                                                    15.0       20.0               False
#                                                    20.0       25.0               False
# ...                                                                                ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0               False
#                                                    40.0       45.0               False
#                                                    45.0       50.0               False
#                                                    50.0       55.0               False
#                                                    55.0       60.0               False
#
#                                                                         Ceblepyris_cinereus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                     False
#                                                    5.0        10.0                    False
#                                                    10.0       15.0                    False
#                                                    15.0       20.0                    False
#                                                    20.0       25.0                    False
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                    False
#                                                    40.0       45.0                    False
#                                                    45.0       50.0                    False
#                                                    50.0       55.0                    False
#                                                    55.0       60.0                    False
#
#                                                                         Neodrepanis_coruscans  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                       False
#                                                    5.0        10.0                      False
#                                                    10.0       15.0                      False
#                                                    15.0       20.0                      False
#                                                    20.0       25.0                      False
# ...                                                                                       ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                      False
#                                                    40.0       45.0                      False
#                                                    45.0       50.0                      False
#                                                    50.0       55.0                      False
#                                                    55.0       60.0                      False
#
#                                                                         Philepitta_castanea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                      True
#                                                    5.0        10.0                     True
#                                                    10.0       15.0                     True
#                                                    15.0       20.0                     True
#                                                    20.0       25.0                    False
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                    False
#                                                    40.0       45.0                    False
#                                                    45.0       50.0                    False
#                                                    50.0       55.0                    False
#                                                    55.0       60.0                    False
#
#                                                                         Eulemur_sp  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0            False
#                                                    5.0        10.0           False
#                                                    10.0       15.0           False
#                                                    15.0       20.0           False
#                                                    20.0       25.0           False
# ...                                                                            ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0           False
#                                                    40.0       45.0           False
#                                                    45.0       50.0           False
#                                                    50.0       55.0           False
#                                                    55.0       60.0           False
#
#                                                                         Coua_cristata  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0               False
#                                                    5.0        10.0              False
#                                                    10.0       15.0              False
#                                                    15.0       20.0              False
#                                                    20.0       25.0              False
# ...                                                                               ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0              False
#                                                    40.0       45.0              False
#                                                    45.0       50.0              False
#                                                    50.0       55.0              False
#                                                    55.0       60.0              False
#
#                                                                         Treron_australis
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                  False
#                                                    5.0        10.0                 False
#                                                    10.0       15.0                 False
#                                                    15.0       20.0                 False
#                                                    20.0       25.0                 False
# ...                                                                                  ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                 False
#                                                    40.0       45.0                 False
#                                                    45.0       50.0                 False
#                                                    50.0       55.0                 False
#                                                    55.0       60.0                 False
#
# [1476 rows x 19 columns]

# %%
# make predictions by passing the embeddings through the classifier
preds = perch_model.network(torch.tensor(emb_val).float()).detach().numpy()

preds = pd.DataFrame(preds,index=val_labels.index,columns=val_labels.columns)
preds
# Out:
#                                                                         Hypsipetes_madagascariensis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                          0.442242
#                                                    5.0        10.0                        -1.219409
#                                                    10.0       15.0                        -0.712239
#                                                    15.0       20.0                        -1.364011
#                                                    20.0       25.0                        -1.793821
# ...                                                                                             ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                        -2.360789
#                                                    40.0       45.0                        -2.429667
#                                                    45.0       50.0                        -2.700440
#                                                    50.0       55.0                        -3.310641
#                                                    55.0       60.0                        -1.454336
#
#                                                                         Copsychus_albospecularis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                      -3.348387
#                                                    5.0        10.0                     -4.616866
#                                                    10.0       15.0                     -4.998057
#                                                    15.0       20.0                     -1.820592
#                                                    20.0       25.0                     -4.274250
# ...                                                                                          ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                     -4.085237
#                                                    40.0       45.0                     -4.516417
#                                                    45.0       50.0                     -2.753410
#                                                    50.0       55.0                     -4.469221
#                                                    55.0       60.0                     -3.144888
#
#                                                                         Coracopsis_nigra  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0              -3.387710
#                                                    5.0        10.0             -2.736251
#                                                    10.0       15.0             -2.891055
#                                                    15.0       20.0             -3.308431
#                                                    20.0       25.0             -2.275124
# ...                                                                                  ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0             -4.229442
#                                                    40.0       45.0             -5.080958
#                                                    45.0       50.0             -4.416505
#                                                    50.0       55.0             -5.230480
#                                                    55.0       60.0             -4.832216
#
#                                                                         Dicrurus_forficatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                 -3.176146
#                                                    5.0        10.0                -3.408050
#                                                    10.0       15.0                -2.590180
#                                                    15.0       20.0                -3.208764
#                                                    20.0       25.0                -4.285195
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                -0.660929
#                                                    40.0       45.0                -2.161160
#                                                    45.0       50.0                -1.368272
#                                                    50.0       55.0                -1.785869
#                                                    55.0       60.0                -2.258831
#
#                                                                         Coua_caerulea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0           -2.758484
#                                                    5.0        10.0          -2.214860
#                                                    10.0       15.0          -2.726237
#                                                    15.0       20.0          -2.970883
#                                                    20.0       25.0          -3.875875
# ...                                                                               ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0          -4.655530
#                                                    40.0       45.0          -5.648482
#                                                    45.0       50.0          -5.698330
#                                                    50.0       55.0          -5.618594
#                                                    55.0       60.0          -4.253419
#
#                                                                         Zosterops_maderaspatanus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                      -3.791548
#                                                    5.0        10.0                     -4.465325
#                                                    10.0       15.0                     -4.672232
#                                                    15.0       20.0                     -3.508624
#                                                    20.0       25.0                     -4.759165
# ...                                                                                          ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                     -5.375675
#                                                    40.0       45.0                     -4.901549
#                                                    45.0       50.0                     -5.419599
#                                                    50.0       55.0                     -5.624104
#                                                    55.0       60.0                     -5.137795
#
#                                                                         Eurystomus_glaucurus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                  -1.726261
#                                                    5.0        10.0                 -3.016299
#                                                    10.0       15.0                 -2.232301
#                                                    15.0       20.0                 -2.634394
#                                                    20.0       25.0                 -2.855699
# ...                                                                                      ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                 -5.068646
#                                                    40.0       45.0                 -4.588596
#                                                    45.0       50.0                 -4.902130
#                                                    50.0       55.0                 -6.019722
#                                                    55.0       60.0                 -4.792081
#
#                                                                         Agapornis_canus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0             -5.531766
#                                                    5.0        10.0            -6.492440
#                                                    10.0       15.0            -6.557611
#                                                    15.0       20.0            -5.953173
#                                                    20.0       25.0            -5.917602
# ...                                                                                 ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0            -1.188361
#                                                    40.0       45.0            -1.789830
#                                                    45.0       50.0            -1.854809
#                                                    50.0       55.0            -2.473473
#                                                    55.0       60.0            -1.828887
#
#                                                                         Saxicola_torquatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                -4.531032
#                                                    5.0        10.0               -5.929832
#                                                    10.0       15.0               -4.642052
#                                                    15.0       20.0               -4.338316
#                                                    20.0       25.0               -3.741129
# ...                                                                                    ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0               -5.135716
#                                                    40.0       45.0               -4.141860
#                                                    45.0       50.0               -4.956173
#                                                    50.0       55.0               -5.150227
#                                                    55.0       60.0               -4.886095
#
#                                                                         Cyanolanius_madagascarinus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                        -5.612969
#                                                    5.0        10.0                       -5.424864
#                                                    10.0       15.0                       -4.346560
#                                                    15.0       20.0                       -5.274891
#                                                    20.0       25.0                       -4.146592
# ...                                                                                            ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                       -3.268222
#                                                    40.0       45.0                       -2.263101
#                                                    45.0       50.0                       -2.489110
#                                                    50.0       55.0                       -3.106046
#                                                    55.0       60.0                       -3.044168
#
#                                                                         Leptopterus_chabert  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                 -4.941016
#                                                    5.0        10.0                -4.782973
#                                                    10.0       15.0                -5.277384
#                                                    15.0       20.0                -5.929341
#                                                    20.0       25.0                -4.604073
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                -4.002113
#                                                    40.0       45.0                -3.693347
#                                                    45.0       50.0                -4.148547
#                                                    50.0       55.0                -3.750916
#                                                    55.0       60.0                -4.338118
#
#                                                                         Nesoenas_picturatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                 -5.570312
#                                                    5.0        10.0                -4.585343
#                                                    10.0       15.0                -5.625156
#                                                    15.0       20.0                -5.575891
#                                                    20.0       25.0                -4.687821
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                -4.969312
#                                                    40.0       45.0                -3.571003
#                                                    45.0       50.0                -4.837775
#                                                    50.0       55.0                -4.330064
#                                                    55.0       60.0                -6.414718
#
#                                                                         Coua_reynaudii  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0            -4.833560
#                                                    5.0        10.0           -5.214698
#                                                    10.0       15.0           -5.286535
#                                                    15.0       20.0           -4.789639
#                                                    20.0       25.0           -6.354001
# ...                                                                                ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0           -4.902915
#                                                    40.0       45.0           -3.200659
#                                                    45.0       50.0           -4.062730
#                                                    50.0       55.0           -4.537431
#                                                    55.0       60.0           -4.872752
#
#                                                                         Ceblepyris_cinereus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                 -5.047613
#                                                    5.0        10.0                -6.972955
#                                                    10.0       15.0                -4.725681
#                                                    15.0       20.0                -4.582778
#                                                    20.0       25.0                -5.240793
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                -4.317413
#                                                    40.0       45.0                -3.964896
#                                                    45.0       50.0                -3.110538
#                                                    50.0       55.0                -3.633217
#                                                    55.0       60.0                -3.974769
#
#                                                                         Neodrepanis_coruscans  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                   -0.233732
#                                                    5.0        10.0                  -6.080317
#                                                    10.0       15.0                  -5.516841
#                                                    15.0       20.0                  -0.845362
#                                                    20.0       25.0                  -2.963242
# ...                                                                                       ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                  -3.757404
#                                                    40.0       45.0                  -4.731263
#                                                    45.0       50.0                  -4.725732
#                                                    50.0       55.0                  -5.235893
#                                                    55.0       60.0                  -4.367478
#
#                                                                         Philepitta_castanea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0                 -4.271549
#                                                    5.0        10.0                -6.051753
#                                                    10.0       15.0                -4.509672
#                                                    15.0       20.0                -5.686746
#                                                    20.0       25.0                -5.619401
# ...                                                                                     ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0                -3.629740
#                                                    40.0       45.0                -3.055600
#                                                    45.0       50.0                -4.019987
#                                                    50.0       55.0                -3.272608
#                                                    55.0       60.0                -4.220442
#
#                                                                         Eulemur_sp  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0        -3.468028
#                                                    5.0        10.0       -4.560950
#                                                    10.0       15.0       -4.310977
#                                                    15.0       20.0       -4.621077
#                                                    20.0       25.0       -4.010249
# ...                                                                            ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0       -2.045920
#                                                    40.0       45.0       -1.696559
#                                                    45.0       50.0       -3.433789
#                                                    50.0       55.0       -3.073862
#                                                    55.0       60.0       -3.734633
#
#                                                                         Coua_cristata  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0           -5.137953
#                                                    5.0        10.0          -6.271206
#                                                    10.0       15.0          -5.698793
#                                                    15.0       20.0          -5.260771
#                                                    20.0       25.0          -6.355299
# ...                                                                               ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0          -5.394368
#                                                    40.0       45.0          -5.986300
#                                                    45.0       50.0          -5.206092
#                                                    50.0       55.0          -5.142474
#                                                    55.0       60.0          -6.528818
#
#                                                                         Treron_australis
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        5.0              -2.790385
#                                                    5.0        10.0             -4.585757
#                                                    10.0       15.0             -4.060497
#                                                    15.0       20.0             -3.756717
#                                                    20.0       25.0             -3.917587
# ...                                                                                  ...
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 35.0       40.0             -5.882690
#                                                    40.0       45.0             -5.539563
#                                                    45.0       50.0             -5.720546
#                                                    50.0       55.0             -6.150178
#                                                    55.0       60.0             -6.133996
#
# [1476 rows x 19 columns]

# %%
# plot histogram of scores for positive and negative clips
plt.hist(preds[val_labels==True],bins=20,alpha=0.5,label='positives')
plt.hist(preds[val_labels==False],bins=20,alpha=0.5,label='negatives')
plt.legend()
plt.semilogy()

# calculate the area under the ROC score
roc_auc_score(val_labels.values,preds,average=None)
# Out:
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/matplotlib_inline/config.py:68: DeprecationWarning: InlineBackend._figure_format_changed is deprecated in traitlets 4.1: use @observe and @unobserve instead.
#   def _figure_format_changed(self, name, old, new):
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/matplotlib/axes/_axes.py:7065: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/matplotlib/axes/_axes.py:7066: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# array([0.91695192, 0.98892606, 0.98969883, 0.99245906, 0.98719423,
#        0.99188978, 0.99894508, 0.9872442 , 0.99965753, 0.98997962,
#        0.98603785,        nan,        nan, 0.81478969, 0.99751075,
#        0.61862678, 0.94754434,        nan, 0.89694915])

# %%
histspecies = 'Zosterops_maderaspatanus'
# Filter
df_Pos = preds[val_labels==True]
df_NOT = preds[val_labels==False]
# Plot histograms
plt.hist(df_NOT[histspecies],bins=20,alpha=0.5,label='negatives')
plt.hist(df_Pos[histspecies],bins=20,alpha=0.5,label='positives')
# Add a legend and labels
plt.legend()
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.semilogy()
# Show the plot
plt.show()

# %%
avprecscore_auroc_by_sp = pd.DataFrame(columns=['species', 'avg_precision_score','auroc_score'])
for species in class_list:
    avgscore = sklearn.metrics.average_precision_score(val_labels [species],preds [species])
    auroc = sklearn.metrics.roc_auc_score(val_labels[species],preds [species])
    new_row = pd.DataFrame({'species': [species], 'avg_precision_score': [avgscore], 'auroc_score': [auroc]})
    avprecscore_auroc_by_sp = pd.concat([avprecscore_auroc_by_sp, new_row], ignore_index=True)

avprecscore_auroc_by_sp
# Out:
# /tmp/ipykernel_370553/3174497413.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   avprecscore_auroc_by_sp = pd.concat([avprecscore_auroc_by_sp, new_row], ignore_index=True)
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/Sheila/miniconda3/envs/rewilding_tensorflow/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#                         species  avg_precision_score  auroc_score
# 0   Hypsipetes_madagascariensis             0.846059     0.916952
# 1      Copsychus_albospecularis             0.795245     0.988926
# 2              Coracopsis_nigra             0.830705     0.989699
# 3           Dicrurus_forficatus             0.900632     0.992459
# 4                 Coua_caerulea             0.801678     0.987194
# 5      Zosterops_maderaspatanus             0.492993     0.991890
# 6          Eurystomus_glaucurus             0.937863     0.998945
# 7               Agapornis_canus             0.512439     0.987244
# 8            Saxicola_torquatus             0.961838     0.999658
# 9    Cyanolanius_madagascarinus             0.553102     0.989980
# 10          Leptopterus_chabert             0.716216     0.986038
# 11          Nesoenas_picturatus             0.000000          NaN
# 12               Coua_reynaudii             0.000000          NaN
# 13          Ceblepyris_cinereus             0.051855     0.814790
# 14        Neodrepanis_coruscans             0.738095     0.997511
# 15          Philepitta_castanea             0.006365     0.618627
# 16                   Eulemur_sp             0.223576     0.947544
# 17                Coua_cristata             0.000000          NaN
# 18             Treron_australis             0.006536     0.896949

# %%
avprecscore_auroc_by_sp.to_csv(f'/mnt/class_data/group1_bioacoustics/sheila/results/{filename}.csv')
