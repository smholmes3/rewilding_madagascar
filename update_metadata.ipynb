# %%
import pandas as pd
from glob import glob

# %%
metadata = pd.read_csv('./data/raven_annotations_metadata_path.csv')
metadata.head()
# Out:
#    Unnamed: 0  Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0           0        0.763354      3.078034       2854.369        5965.410
# 1           1        6.588949      9.475884       2571.297        5451.150
# 2           2       10.434780     12.523959       3085.557        5348.299
# 3           3       14.854197     15.436757       3085.557        5862.558
# 4           4       55.578030     59.479764       2621.359        5475.728
#
#                Species  Conf Call_type                         Filename  \
# 0  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 1  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 2  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 3  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 4  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
#
#   SiteHab RecordingSched RecorderName     DP                        SoundFile  \
# ...

# %%
ravenfile = 'AGN_A-AGN04_20230429_054000.txt'
glob(f'/mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/*/{ravenfile}')[0]
# Out:
# '/mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN04_20230429_054000.txt'

# %%
metadata['Raven_path'] = metadata['Filename'].apply(lambda ravenfile:glob(f'/mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/*/{ravenfile}')[0])

# %%
metadata.head()
# Out:
#    Unnamed: 0  Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0           0        0.763354      3.078034       2854.369        5965.410
# 1           1        6.588949      9.475884       2571.297        5451.150
# 2           2       10.434780     12.523959       3085.557        5348.299
# 3           3       14.854197     15.436757       3085.557        5862.558
# 4           4       55.578030     59.479764       2621.359        5475.728
#
#                Species  Conf Call_type                         Filename  \
# 0  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 1  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 2  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 3  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 4  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
#
#   SiteHab RecordingSched RecorderName     DP                        SoundFile  \
# ...

# %%
metadata['SoundFile_path'] = '/mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/' + metadata['Split'] + '/' + metadata['SoundFile_path']

# %%
metadata.head()
# Out:
#    Unnamed: 0  Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0           0        0.763354      3.078034       2854.369        5965.410
# 1           1        6.588949      9.475884       2571.297        5451.150
# 2           2       10.434780     12.523959       3085.557        5348.299
# 3           3       14.854197     15.436757       3085.557        5862.558
# 4           4       55.578030     59.479764       2621.359        5475.728
#
#                Species  Conf Call_type                         Filename  \
# 0  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 1  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 2  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 3  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 4  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
#
#   SiteHab RecordingSched RecorderName     DP                        SoundFile  \
# ...

# %%
metadata['SoundFile_path'] = metadata['SoundFile_path'].apply(lambda x:x.replace('\\', '/'))
metadata.head()
# Out:
#    Unnamed: 0  Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0           0        0.763354      3.078034       2854.369        5965.410
# 1           1        6.588949      9.475884       2571.297        5451.150
# 2           2       10.434780     12.523959       3085.557        5348.299
# 3           3       14.854197     15.436757       3085.557        5862.558
# 4           4       55.578030     59.479764       2621.359        5475.728
#
#                Species  Conf Call_type                         Filename  \
# 0  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 1  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 2  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 3  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
# 4  Philepitta_castanea   NaN       NaN  AGN_A-AGN04_20230429_054000.txt
#
#   SiteHab RecordingSched RecorderName     DP                        SoundFile  \
# ...

# %%
metadata.SoundFile_path[0]
# Out:
# '/mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Marojejy/AGN_A/AGN_A-AGN04/AGN_A-AGN04_20230429_054000.WAV'

# %%
ls /mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Marojejy/AGN_A/AGN_A-AGN04/AGN_A-AGN04_20230429_054000.WAV
# Out:
# /mnt/class_data/group1_bioacoustics/sheila/cv4e_dataset/validation/Marojejy/AGN_A/AGN_A-AGN04/AGN_A-AGN04_20230429_054000.WAV

# %%
metadata.to_csv('metadata.csv',index=False)

# %%
metadata.Raven_path[0]
# Out:
# '/mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN04_20230429_054000.txt'

# %%
for ravenfile in metadata.Raven_path:
    
    df = pd.read_csv(ravenfile, delimiter='\t')
    df.rename(columns = {'Species':'species'},inplace=True)
    df.to_csv(ravenfile,sep = "\t",index = False)
    print(ravenfile)
             #save as tab delimited
             #If confident, change temp to ravenfile and remove break
# Out:
# /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN04_20230429_054000.txt
# /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN04_20230429_054000.txt
# /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN04_20230429_054000.txt
# /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN04_20230429_054000.txt
# /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN04_20230429_054000.txt
# /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN08_20230421_084000.txt
# /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN08_20230517_164000.txt
# /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Marojejy/AGN_A-AGN08_20230517_164000.txt
# ...

# %%
cat /mnt/class_data/group1_bioacoustics/sheila/Processed_raven_annotations/Analalava/NLR_B-NLR03_20230123_065400.txt
# Out:
# Selection	View	Channel	Begin Time (s)	End Time (s)	Low Freq (Hz)	High Freq (Hz)	Delta Time (s)	Delta Freq (Hz)	Avg Power Density (dB FS/Hz)	species
# 1	Spectrogram 1	1	0.7386363	4.318181443	1674.727	4410.113	3.5795	2735.386	-54.55	Hypsipetes_madagascariensis
# 2	Spectrogram 1	1	4.772726858	10.014449998	2121.32	4996.268	5.2417	2874.948	-56.46	Hypsipetes_madagascariensis
# 3	Spectrogram 1	1	10.681817255	17.556816658	979.071	6556.808	6.875	5577.737	-50.29	Hypsipetes_madagascariensis
# 4	Spectrogram 1	1	19.898842203	23.977270646	1869.135	4658.004	4.0784	2788.869	-56.72	Hypsipetes_madagascariensis
# 5	Spectrogram 1	1	24.602270592	28.522724797	1958.142	4965.5	3.9205	3007.358	-64.51	Hypsipetes_madagascariensis
# 6	Spectrogram 1	1	28.806815681	41.445083108	1869.135	5073.368	12.6383	3204.233	-58.04	Hypsipetes_madagascariensis
# 7	Spectrogram 1	1	42.225429861	47.727268584	1780.129	5548.069	5.5018	3767.94	-57.89	Hypsipetes_madagascariensis
# ...
