# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from opensoundscape import BoxedAnnotations, CNN
from opensoundscape import SpectrogramPreprocessor

# %%
notebook_name = 'CNN_model_overlay.ipynb'
epochs = 20
save_path= '/mnt/class_data/group1_bioacoustics/sheila/model_checkpoints/model_7_overlay'
log_interval=20
batch_size=256
n_samples_per_class = 5221
sample_duration=2
window_samples = 2048
min_f=0
max_f=9000
step_size = 10
gamma = 0.5

# %%
train_labels = pd.read_csv('data/train_labels.csv',index_col=['file', 'start_time', 'end_time'])
val_labels = pd.read_csv('data/val_labels.csv',index_col=['file', 'start_time', 'end_time'])
test_labels = pd.read_csv('data/test_labels.csv',index_col=['file', 'start_time', 'end_time'])
train_labels.head()
# Out:
#                                                                         Hypsipetes_madagascariensis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                             False
#                                                    2.0        4.0                             False
#                                                    4.0        6.0                             False
#                                                    6.0        8.0                             False
#                                                    8.0        10.0                            False
#
#                                                                         Copsychus_albospecularis  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                          False
#                                                    2.0        4.0                          False
#                                                    4.0        6.0                          False
#                                                    6.0        8.0                          False
#                                                    8.0        10.0                         False
#
#                                                                         Coracopsis_nigra  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                  False
#                                                    2.0        4.0                  False
#                                                    4.0        6.0                  False
#                                                    6.0        8.0                  False
#                                                    8.0        10.0                 False
#
#                                                                         Dicrurus_forficatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Coua_caerulea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0               False
#                                                    2.0        4.0               False
#                                                    4.0        6.0               False
#                                                    6.0        8.0               False
#                                                    8.0        10.0              False
#
#                                                                         Zosterops_maderaspatanus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                          False
#                                                    2.0        4.0                          False
#                                                    4.0        6.0                          False
#                                                    6.0        8.0                          False
#                                                    8.0        10.0                         False
#
#                                                                         Eurystomus_glaucurus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                      False
#                                                    2.0        4.0                      False
#                                                    4.0        6.0                      False
#                                                    6.0        8.0                      False
#                                                    8.0        10.0                     False
#
#                                                                         Agapornis_canus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                 False
#                                                    2.0        4.0                 False
#                                                    4.0        6.0                 False
#                                                    6.0        8.0                 False
#                                                    8.0        10.0                False
#
#                                                                         Saxicola_torquatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                    False
#                                                    2.0        4.0                    False
#                                                    4.0        6.0                    False
#                                                    6.0        8.0                    False
#                                                    8.0        10.0                   False
#
#                                                                         Cyanolanius_madagascarinus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                            False
#                                                    2.0        4.0                            False
#                                                    4.0        6.0                            False
#                                                    6.0        8.0                            False
#                                                    8.0        10.0                           False
#
#                                                                         Leptopterus_chabert  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Nesoenas_picturatus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Coua_reynaudii  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                False
#                                                    2.0        4.0                False
#                                                    4.0        6.0                False
#                                                    6.0        8.0                False
#                                                    8.0        10.0               False
#
#                                                                         Ceblepyris_cinereus  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Neodrepanis_coruscans  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                       False
#                                                    2.0        4.0                       False
#                                                    4.0        6.0                       False
#                                                    6.0        8.0                       False
#                                                    8.0        10.0                      False
#
#                                                                         Philepitta_castanea  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                     False
#                                                    2.0        4.0                     False
#                                                    4.0        6.0                     False
#                                                    6.0        8.0                     False
#                                                    8.0        10.0                    False
#
#                                                                         Eulemur_sp  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0            False
#                                                    2.0        4.0            False
#                                                    4.0        6.0            False
#                                                    6.0        8.0            False
#                                                    8.0        10.0           False
#
#                                                                         Coua_cristata  \
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0               False
#                                                    2.0        4.0               False
#                                                    4.0        6.0               False
#                                                    6.0        8.0               False
#                                                    8.0        10.0              False
#
#                                                                         Treron_australis
# file                                               start_time end_time
# /mnt/class_data/group1_bioacoustics/sheila/cv4e... 0.0        2.0                  False
#                                                    2.0        4.0                  False
#                                                    4.0        6.0                  False
#                                                    6.0        8.0                  False
#                                                    8.0        10.0                 False

# %%
# pick classes to train the model on. These should occur in the annotated data
class_list = ['Hypsipetes_madagascariensis','Copsychus_albospecularis','Coracopsis_nigra','Dicrurus_forficatus','Coua_caerulea','Zosterops_maderaspatanus','Eurystomus_glaucurus','Agapornis_canus','Saxicola_torquatus','Cyanolanius_madagascarinus','Leptopterus_chabert','Nesoenas_picturatus','Coua_reynaudii','Ceblepyris_cinereus','Neodrepanis_coruscans','Philepitta_castanea','Eulemur_sp','Coua_cristata','Treron_australis']

class_list==train_labels.columns.values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
train_labels_resampled = opensoundscape.data_selection.resample(train_labels,n_samples_per_class = n_samples_per_class, downsample = False,upsample = True)

# %%
import wandb
'''wandb.login()'''#when logging in on a new machine
wandb_session = wandb.init(
    project='Rewilding_Madagascar',
)

# %%
#create new model and change parameters then visualize
# create a CNN and train on the labeled data
model = CNN(architecture='resnet18', sample_duration=sample_duration, classes=class_list)

# %%
#Include a step in my preprocessing that does the overlay - it will pick a sample from overlay df and combine with sample currently pre-processing
my_preprocessor = SpectrogramPreprocessor(sample_duration = sample_duration, overlay_df=train_labels_resampled)
model.preprocessor = my_preprocessor

# %%
#changes learning rate over time
#default is wait a certain number of epochs and then multiply by x (step learning)
model.lr_scheduler_params['kwargs']['step_size'] = step_size
model.lr_scheduler_params['kwargs']['gamma'] = gamma

# %%
model.preprocessor.pipeline.bandpass.set(min_f=min_f,max_f=max_f)
model.preprocessor.pipeline.to_spec.params.window_samples = window_samples
model.train(train_labels_resampled, val_labels, epochs=epochs, log_interval=log_interval, num_workers=8, batch_size=batch_size, wandb_session = wandb_session, save_path= save_path)
wandb_session.finish()
# Out:
# Training Epoch 0
#   0%|          | 0/388 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 model.preprocessor.pipeline.bandpass.set(min_f=min_f,max_f=max_f)
#       2 model.preprocessor.pipeline.to_spec.params.window_samples = window_samples
# ----> 3 model.train(train_labels_resampled, val_labels, epochs=epochs, log_interval=log_interval, num_workers=8, batch_size=batch_size, wandb_session = wandb_session, save_path= save_path)
#       4 wandb_session.finish()
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/opensoundscape/ml/cnn.py:1622, in SpectrogramClassifier.train(self, train_df, validation_df, epochs, batch_size, num_workers, save_path, save_interval, log_interval, validation_interval, reset_optimizer, restart_scheduler, invalid_samples_log, raise_errors, wandb_session, progress_bar)
#    1615 for epoch in range(epochs):
#    1616     # 1 epoch = 1 view of each training sample
#    1617     # loss fn, backpropogation, and optimizer step generally occur after each batch
#    1618     # validation generally occurs after validation_interval epochs
#    1619
#    1620     ### Training ###
#    1621     self._log(f"\nTraining Epoch {self.current_epoch}")
# -> 1622     train_metrics = self._train_epoch(
#    1623         train_loader, wandb_session, progress_bar=progress_bar
#    1624     )
#    1626     #### Validation ###
#    1627     if epoch % validation_interval == 0:
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/opensoundscape/ml/cnn.py:1346, in SpectrogramClassifier._train_epoch(self, train_loader, wandb_session, progress_bar)
#    1343 self.network.train()
#    1344 batch_loss = []
# -> 1346 for batch_idx, (batch_tensors, batch_labels) in enumerate(
#    1347     tqdm(train_loader, disable=not progress_bar)
#    1348 ):
#    1349     # save loss for each batch; later take average for epoch
#    1350     loss = self.training_step((batch_tensors, batch_labels), batch_idx)
#    1351     batch_loss.append(loss.detach().cpu().numpy())
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1448, in _MultiProcessingDataLoaderIter._next_data(self)
#    1445     return self._process_data(data)
#    1447 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1448 idx, data = self._get_data()
#    1449 self._tasks_outstanding -= 1
#    1450 if self._dataset_kind == _DatasetKind.Iterable:
#    1451     # Check for _IterableDatasetStopIteration
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1402, in _MultiProcessingDataLoaderIter._get_data(self)
#    1400 elif self._pin_memory:
#    1401     while self._pin_memory_thread.is_alive():
# -> 1402         success, data = self._try_get_data()
#    1403         if success:
#    1404             return data
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1243, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1230 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1231     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1232     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1240     # Returns a 2-tuple:
#    1241     #   (bool: whether successfully get data, any: data if successful else None)
#    1242     try:
# -> 1243         data = self._data_queue.get(timeout=timeout)
#    1244         return (True, data)
#    1245     except Exception as e:
#    1246         # At timeout and error, we manually check whether any worker has
#    1247         # failed. Note that this is the only mechanism for Windows to detect
#    1248         # worker failures.
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File ~/miniconda3/envs/rewild_cv4e/lib/python3.11/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x77155afb0720>
# Traceback (most recent call last):
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/home/Sheila/miniconda3/envs/rewild_cv4e/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process

# %%
import nbformat as nbf
import json

# Load the current notebook
with open(notebook_name) as f:
    nb = nbf.read(f, as_version=4)


# Save the notebook to the new path
with open(save_path, 'w') as f:
    nbf.write(nb, f)
